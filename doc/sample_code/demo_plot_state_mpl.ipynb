# %%
import sys
sys.path.append('./../../')

from pyogi.board import *

# %%
board = Board()
board.set_initial_state()
board.players = ['先手の人', '後手の人']

moves = ['+7776FU', '-3334FU', '+2726FU', '-4132KI', '+6978KI']

for move in moves:
    board.move(move)
    
board.plot_state_mpl(title='5手目: ☗７八金まで', savepath='example_mpl.png')

# %%
# %load_ext version_information
# %version_information matplotlib
# Out:
# Software versions
# Python 3.4.2 64bit [GCC 4.8.2]
# IPython 2.4.1
# OS Linux 3.13.0 57 generic x86_64 with debian jessie sid
# matplotlib 1.4.3
# Mon Jul 20 14:38:54 2015 JST
